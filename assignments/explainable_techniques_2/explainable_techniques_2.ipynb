# %% [markdown]
# # Explainable Techniques II
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/ericiortega/aipi590-xai-fall2025/blob/main/assignments/explainable_techniques_2/explainable_techniques_2.ipynb)
#
# This assignment applies advanced explainability methods (PDP, ICE, ALE) to a chosen model and dataset...
